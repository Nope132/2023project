# %%
import urllib.robotparser

# %%
parser=urllib.robotparser.RobotFileParser()

# %%
parser.set_url("https://www.baidu.com/robots.txt")

# %%
parser.read()

# %%
parser.can_fetch("Baiduspider","https://www.baidu.com/baidu")
# Out:
# False

# %%
parser.can_fetch("Baiduspider","https://www.baidu.com/mybaidu")
# Out:
# True

# %%
import requests

# %%
respnse =requests.get("http://httpbin.org/get")

# %%
respnse.status_code
# Out:
# 200

# %%
if respnse.status_code ==200:

# %%
respnse.encoding
# Out:
# 'utf-8'

# %%
respnse.apparent_encoding
# Out:
# 'ascii'

# %%
respnse.encoding=respnse.apparent.encoding
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\temp/ipykernel_9336/2669309075.py in <module>
# ----> 1 respnse.encoding=respnse.apparent.encoding
#
# AttributeError: 'Response' object has no attribute 'apparent'

# %%
print(respnse.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-6553160d-4aa6cbb527e6b27c0794f8a4"
#   },
#   "origin": "39.144.55.68",
#   "url": "http://httpbin.org/get"
# }

# %%
print("mhbsb")
# Out:
# mhbsb

# %%
import re

# %%
pattern =re.compile(r"\d+")

# %%
sentence="12 hello world 345"

# %%
pattern.findall(sentence)
# Out:
# ['12', '345']

# %%
re.match(r"\d+",sentence)
# Out:
# <re.Match object; span=(0, 2), match='12'>

# %%
m=re.match(r"\d+",sentence)
if m is not None:
    print(m.group())
else:
    print("not matched")
# Out:
# 12

# %%
re.search("hello",sentence)
# Out:
# <re.Match object; span=(3, 8), match='hello'>

# %%
m=re.match(r"(abc)|(def)","abcd")

# %%
m.group(2)

# %%
m.group(1)
# Out:
# 'abc'

# %%
m=re.match(r"x(\d+)=\1","x123=123")
if m: 
    print (m.group(1))
# Out:
# 123

# %%
m=re.match(r"(a(b)c)d","abcd")

# %%
m.group(0)
# Out:
# 'abcd'

# %%
# !pip install libcst
# Out:
# ...
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
tree.body[0].targets[0]

# %%
tree = ast.parse("a=1")

# %%
import ast

# %%
import requests

# %%
res=requests.get("http://con.zhilei.ren/crawlme.html")

# %%
print(res.text)
# Out:
# <html>
# 	<head>
# 		<meta http-equiv="content-type" content="text/html; charset=utf-8">
# 		<title>Crawlme</title>
# 	</head>
# 	<body>
# 		<h1 id="heading">Crawl me with your spider</h1>
# 		<p>
# 		è¿éæ¯ä¸æ®µä¸­æï¼å¶ä¸­æä¸ä¸ªé¾æ¥ï¼<a
# 			href="http://oscar-lab.org">æ³æ</a>
# 		</p>
# 		<h2>è¡¨æ ¼</h2>
# 		<hr/>
# 		<p class="mytable">ä¸é¢æ¯ä¸ä¸ªè¡¨æ ¼A</p>
# 		<table border="1" id="table1">
# 			<tr>
# 				<td>A00</td>
# 				<td>A01</td>
# 				<td><a href="http://oscar-lab.org/people/~zren">A02</a></td>
# 			</tr>
# 			<tr>
# 				<td>A10</td>
# 				<td>A11</td>
# 				<td>A12</td>
# 			</tr>
# 			<tr>
# 				<td>A20</td>
# 				<td>A21</td>
# 				<td>A22</td>
# 			</tr>
# 		</table>
# 		<h2>åè¡¨</h2>
# 		<hr/>
# 		<h3>æåº</h3>
# 		<p class="myol">ä¸é¢æ¯ä¸ä¸ªæåºåè¡¨</p>
# 		<ol>
# 			<li>ç¬¬ä¸æ¡</li>
# 			<li>ç¬¬äºæ¡</li>
# 			<li>ç¬¬ä¸æ¡</li>
# 		</ol>
# 		<h3>æ åº</h3>
# 		<p>ä¸é¢æ¯ä¸ä¸ªæ åºåè¡¨</p>
# 		<ul>
# ...

# %%
res.encoding=res.apparent_encoding

# %%
res.text
# Out:
# '<html>\n\t<head>\n\t\t<meta http-equiv="content-type" content="text/html; charset=utf-8">\n\t\t<title>Crawlme</title>\n\t</head>\n\t<body>\n\t\t<h1 id="heading">Crawl me with your spider</h1>\n\t\t<p>\n\t\t这里是一段中文，其中有一个链接：<a\n\t\t\thref="http://oscar-lab.org">戳我</a>\n\t\t</p>\n\t\t<h2>表格</h2>\n\t\t<hr/>\n\t\t<p class="mytable">下面是一个表格A</p>\n\t\t<table border="1" id="table1">\n\t\t\t<tr>\n\t\t\t\t<td>A00</td>\n\t\t\t\t<td>A01</td>\n\t\t\t\t<td><a href="http://oscar-lab.org/people/~zren">A02</a></td>\n\t\t\t</tr>\n\t\t\t<tr>\n\t\t\t\t<td>A10</td>\n\t\t\t\t<td>A11</td>\n\t\t\t\t<td>A12</td>\n\t\t\t</tr>\n\t\t\t<tr>\n\t\t\t\t<td>A20</td>\n\t\t\t\t<td>A21</td>\n\t\t\t\t<td>A22</td>\n\t\t\t</tr>\n\t\t</table>\n\t\t<h2>列表</h2>\n\t\t<hr/>\n\t\t<h3>有序</h3>\n\t\t<p class="myol">下面是一个有序列表</p>\n\t\t<ol>\n\t\t\t<li>第一条</li>\n\t\t\t<li>第二条</li>\n\t\t\t<li>第三条</li>\n\t\t</ol>\n\t\t<h3>无序</h3>\n\t\t<p>下面是一个无序列表</p>\n\t\t<ul>\n\t\t\t<li>第一条</li>\n\t\t\t<li>第二条</li>\n\t\t\t<li>第三条</li>\n\t\t</ul>\n\t
# ...

# %%
re.findall(r'a href="(.*?)"',res.text)
# Out:
# ['http://oscar-lab.org/people/~zren']

# %%
from bs4 import BeautifulSoup

# %%
doc =BeautifulSoup(res.text)

# %%
doc
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <title>Crawlme</title>
# </head>
# <body>
# <h1 id="heading">Crawl me with your spider</h1>
# <p>
# 		这里是一段中文，其中有一个链接：<a href="http://oscar-lab.org">戳我</a>
# </p>
# <h2>表格</h2>
# <hr/>
# <p class="mytable">下面是一个表格A</p>
# <table border="1" id="table1">
# <tr>
# <td>A00</td>
# <td>A01</td>
# <td><a href="http://oscar-lab.org/people/~zren">A02</a></td>
# </tr>
# <tr>
# <td>A10</td>
# <td>A11</td>
# <td>A12</td>
# </tr>
# <tr>
# <td>A20</td>
# <td>A21</td>
# <td>A22</td>
# </tr>
# </table>
# <h2>列表</h2>
# <hr/>
# <h3>有序</h3>
# <p class="myol">下面是一个有序列表</p>
# <ol>
# <li>第一条</li>
# <li>第二条</li>
# <li>第三条</li>
# </ol>
# <h3>无序</h3>
# <p>下面是一个无序列表</p>
# <ul>
# <li>第一条</li>
# <li>第二条</li>
# <li>第三条</li>
# </ul>
# <h2>下拉列表</h2>
# <hr/>
# <select>
# <option value="alpha">选项1</option>
# <option value="beta">选项2</option>
# <option value="gamma">选项3</option>
# <option value="heiheihei">选项四</option>
# ...

# %%
print(doc.prettify())
# Out:
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <title>
#    Crawlme
#   </title>
#  </head>
#  <body>
#   <h1 id="heading">
#    Crawl me with your spider
#   </h1>
#   <p>
#    这里是一段中文，其中有一个链接：
#    <a href="http://oscar-lab.org">
#     戳我
#    </a>
#   </p>
#   <h2>
#    表格
#   </h2>
#   <hr/>
#   <p class="mytable">
#    下面是一个表格A
#   </p>
#   <table border="1" id="table1">
#    <tr>
#     <td>
#      A00
#     </td>
#     <td>
#      A01
#     </td>
#     <td>
#      <a href="http://oscar-lab.org/people/~zren">
#       A02
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td>
#      A10
#     </td>
#     <td>
#      A11
#     </td>
#     <td>
#      A12
#     </td>
#    </tr>
#    <tr>
#     <td>
#      A20
#     </td>
#     <td>
#      A21
#     </td>
#     <td>
#      A22
#     </td>
#    </tr>
#   </table>
#   <h2>
#    列表
#   </h2>
#   <hr/>
#   <h3>
#    有序
#   </h3>
#   <p class="myol">
#    下面是一个有序列表
#   </p>
#   <ol>
# ...

# %%
doc.title
# Out:
# <title>Crawlme</title>

# %%
doc.a
# Out:
# <a href="http://oscar-lab.org">戳我</a>

# %%
doc.table
# Out:
# <table border="1" id="table1">
# <tr>
# <td>A00</td>
# <td>A01</td>
# <td><a href="http://oscar-lab.org/people/~zren">A02</a></td>
# </tr>
# <tr>
# <td>A10</td>
# <td>A11</td>
# <td>A12</td>
# </tr>
# <tr>
# <td>A20</td>
# <td>A21</td>
# <td>A22</td>
# </tr>
# </table>

# %%
for a in doc.find_all("a"):
    print(a.get("href"))
# Out:
# http://oscar-lab.org
# http://oscar-lab.org/people/~zren

# %%
doc.a.get_text()
# Out:
# '戳我'

# %%
# !pip install graphviz networkx
# Out:
# ...
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import requests,graphviz,networkx
res = requests.get("http://con.zhilei.ren/pep")

# %%
res.status_code
# Out:
# 200

# %%
res.encoding =res.apparent_encoding

# %%
import bs4

# %%
doc= bs4.BeautifulSoup(res.text)

# %%
section = doc.find("section", attrs={"id": "numerical-index"})
print(section)
# Out:
# <section id="numerical-index">
# <h2><a class="toc-backref" href="#numerical-index" role="doc-backlink">Numerical Index</a></h2>
# <table class="pep-zero-table docutils align-default">
# <thead>
# <tr class="row-odd"><th class="head"></th>
# <th class="head">PEP</th>
# <th class="head">Title</th>
# <th class="head">Authors</th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td>P</td>
# <td><a class="pep reference internal" href="./pep-0001.html" title="PEP 1 â PEP Purpose and Guidelines">1</a></td>
# <td><a class="pep reference internal" href="./pep-0001.html" title="PEP 1 â PEP Purpose and Guidelines">PEP Purpose and Guidelines</a></td>
# <td>Warsaw, Hylton, Goodger, Coghlan</td>
# </tr>
# <tr class="row-odd"><td>P</td>
# <td><a class="pep reference internal" href="./pep-0002.html" title="PEP 2 â Procedure for Adding New Modules">2</a></td>
# ...

# %%
section.find("table")
# Out:
# <table class="pep-zero-table docutils align-default">
# <thead>
# <tr class="row-odd"><th class="head"></th>
# <th class="head">PEP</th>
# <th class="head">Title</th>
# <th class="head">Authors</th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td>P</td>
# <td><a class="pep reference internal" href="./pep-0001.html" title="PEP 1 â PEP Purpose and Guidelines">1</a></td>
# <td><a class="pep reference internal" href="./pep-0001.html" title="PEP 1 â PEP Purpose and Guidelines">PEP Purpose and Guidelines</a></td>
# <td>Warsaw, Hylton, Goodger, Coghlan</td>
# </tr>
# <tr class="row-odd"><td>P</td>
# <td><a class="pep reference internal" href="./pep-0002.html" title="PEP 2 â Procedure for Adding New Modules">2</a></td>
# <td><a class="pep reference internal" href="./pep-0002.html" title="PEP 2 â Procedure for Adding New Modules">Procedure for Adding New Modules</a></td>
# <td>Cannon, Faassen</td>
# </tr>
# <tr class="row-even"><td>PW</td>
# ...

# %%
g1 =graphviz.Graph()
g2=networkx.Graph()
for tr in section.table.tbody.find_all("tr"):
    tds = tr.find_all("td")
    authors=tds[-1].text.split(",")
    for a1 in range(len(authors)):
        author1 =authors[a1]
        for author2 in authors[a1+1:]:
            print(f"{author1},{author2}")
# Out:
# Warsaw, Hylton
# Warsaw, Goodger
# Warsaw, Coghlan
#  Hylton, Goodger
#  Hylton, Coghlan
#  Goodger, Coghlan
# Cannon, Faassen
# Cannon, von LÃ¶wis
# Aahz, Baxter
# GvR, Warsaw
# GvR, Warsaw
# GvR, Coghlan
#  Warsaw, Coghlan
# von LÃ¶wis, Cannon
# Goodger, Warsaw
# Goodger, Cannon
#  Warsaw, Cannon
# Warsaw, GvR
# Baxter, Warsaw
# Baxter, GvR
#  Warsaw, GvR
# GvR, Ascher
# Schemenauer, Lemburg
# Barrett, Oliphant
# Wilson, Hettinger
# Zhu, Lielens
# Zadka, GvR
# Yee, GvR
# Zadka, GvR
# Zadka, GvR
# Craig, Zadka
# Craig, Zadka
# Martelli, Evans
# Warsaw, GvR
# Schemenauer, Peters
# Schemenauer, Hetland
#  Peters, Hetland
# Goodger, GvR
# Lemburg, von LÃ¶wis
# Sajip, Mick
# Eppstein, Ewing
# JvR, Moore
# Altis, Cole
# Altis, McNamara
# Altis, Montanaro
# Altis, Wells
#  Cole, McNamara
#  Cole, Montanaro
#  Cole, Wells
#  McNamara, Montanaro
#  McNamara, Wells
#  Montanaro, Wells
# Hudson, Diederich
# Hudson, Coghlan
# Hudson, Peterson
#  Diederich, Coghlan
#  Diederich, Peterson
# ...

# %%
"op,b,c,d".split(",")
# Out:
# ['op', 'b', 'c', 'd']

# %%
print(section)
# Out:
# None

# %%
res = requests.get("http://con.zhilei.ren/pep")

# %%
doc_pep+bs4.BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\temp/ipykernel_3636/2022555301.py in <module>
# ----> 1 doc_pep+bs4.BeautifulSoup
#       2
#       3
#
# NameError: name 'doc_pep' is not defined

# %%
import inspect

# %%
def foo():
    a=10
    a += 20
    return inspect.currentframe()

# %%
frame=foo()

# %%
dir(frame)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'f_back',
#  'f_builtins',
#  'f_code',
#  'f_globals',
#  'f_lasti',
#  'f_lineno',
#  'f_locals',
#  'f_trace',
#  'f_trace_lines',
#  'f_trace_opcodes']

# %%
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\temp/ipykernel_3636/4052217197.py in <module>
# ----> 1 aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
#
# NameError: name 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa' is not defined

# %%
frame.f_locals
# Out:
# {'a': 30}

# %%
frame.f_lineno
# Out:
# 4

# %%
frame.f_code.co_name
# Out:
# 'foo'

# %%
x = 10
def outer():
    x=20
    def inner():
        print(x)
        return inspect.currentframe()
    return inner

# %%
inn = outer()
frame = inn()
# Out:
# 20

# %%
inspect.getclosurevars(inn)
# Out:
# ClosureVars(nonlocals={'x': 20}, globals={'inspect': <module 'inspect' from 'D:\\Anaconda3\\lib\\inspect.py'>}, builtins={'print': <built-in function print>}, unbound={'currentframe'})

# %%
from sys import sttrace
def mytracer(frame,event,arg=None):
    func=frame.f_code.co_name
    lineno=frame.f_lineno
    print(f"event:{event},cunc:{func},lineno:{lineno}")
    return mytracer
def foo(bar):
    if bar>10:
        return bar + 1
    else:
        return bar - 1
def buz():
    return foo(20)
old =settrace(my)
